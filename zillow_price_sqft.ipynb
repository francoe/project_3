# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime 
import seaborn as sns

# %%
# setup file for 2013 - 2017 data
price_sqft = "C:/Users/maque/Dropbox/Rice Data analytics classes/RICEHOU201811DATA2/Project 3/MedianValuePerSqft_2013_2017.csv"

# %%
# read csv file
zillow_2013_2017 = pd.read_csv(price_sqft, low_memory = False)
zillow_2013_2017.head()
# Out:
#    RegionID  RegionName         City State        Metro        CountyName  \
# 0     58196        1001       Agawam    MA  Springfield    Hampden County
# 1     58197        1002      Amherst    MA  Springfield  Hampshire County
# 2     58200        1005        Barre    MA    Worcester  Worcester County
# 3     58201        1007  Belchertown    MA  Springfield  Hampshire County
# 4     58202        1008    Blandford    MA  Springfield    Hampden County
#
#    SizeRank  MedianValueSqft       Date
# 0      5898            131.0  1/31/2013
# 1      4144            168.0  1/31/2013
# 2     11147            102.0  1/31/2013
# 3      6783            127.0  1/31/2013
# 4     14604            116.0  1/31/2013

# %%
# setup file for 2018 - 2019 data
price_sqft_2018 = "C:/Users/maque/Dropbox/Rice Data analytics classes/RICEHOU201811DATA2/Project 3/MedianValuePerSqft_2018_2019.csv"

# %%
zillow_2018_2019 = pd.read_csv(price_sqft_2018, low_memory = False)
zillow_2018_2019.head()
# Out:
#    RegionID  RegionName         City State        Metro        CountyName  \
# 0     58196        1001       Agawam    MA  Springfield    Hampden County
# 1     58197        1002      Amherst    MA  Springfield  Hampshire County
# 2     58200        1005        Barre    MA    Worcester  Worcester County
# 3     58201        1007  Belchertown    MA  Springfield  Hampshire County
# 4     58202        1008    Blandford    MA  Springfield    Hampden County
#
#    SizeRank  MedianValueSqft       Date
# 0      5898              152  1/31/2018
# 1      4144              193  1/31/2018
# 2     11147              143  1/31/2018
# 3      6783              145  1/31/2018
# 4     14604              127  1/31/2018

# %%
zillow_price_sqft = pd.concat([zillow_2013_2017,zillow_2018_2019])
zillow_price_sqft.head()
# Out:
#    RegionID  RegionName         City State        Metro        CountyName  \
# 0     58196        1001       Agawam    MA  Springfield    Hampden County
# 1     58197        1002      Amherst    MA  Springfield  Hampshire County
# 2     58200        1005        Barre    MA    Worcester  Worcester County
# 3     58201        1007  Belchertown    MA  Springfield  Hampshire County
# 4     58202        1008    Blandford    MA  Springfield    Hampden County
#
#    SizeRank  MedianValueSqft       Date
# 0      5898            131.0  1/31/2013
# 1      4144            168.0  1/31/2013
# 2     11147            102.0  1/31/2013
# 3      6783            127.0  1/31/2013
# 4     14604            116.0  1/31/2013

# %%
# df = pd.merge(df,df2[['Key_Column','Target_Column']],on='Key_Column', how='left')
len(zillow_price_sqft['Date'])
# Out:
# 1109325

# %%
# save as csv file
zillow_price_sqft.to_csv('C:/Users/maque/Dropbox/Rice Data analytics classes/RICEHOU201811DATA2/Project 3/zillow_price_sqft.csv', encoding='utf-8', index=False)
