# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
from numpy.random import seed
seed(1)
import pandas as pd

# %%
#import the csv
df = pd.read_csv("complete_data_test1.csv")
# df1 = pd.read_excel('Zillow Data.xlsx')
# df = df.drop(columns=['Median Price', 'Date'])

# df['Sales'] = [float(x.replace(',', '')) for x in df['Sales']]
# df['Dollar Volume'] = [float(x.replace(',', '')) for x in df['Dollar Volume']]
# df['Average Price'] = [float(x.replace(',', '')) for x in df['Average Price']]
# df['Total Listings'] = [float(x.replace(',', '')) for x in df['Total Listings']]


# print(X.shape, y.shape)
df1 = df[['SizeRank', 'unemployment_rate', 'MedianListPrice', 'MORTGAGE30US', 'Avg Income']]
df1

X = df1.drop("MedianListPrice", axis=1)
y = df1["MedianListPrice"]

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train
# y_train.shape
# Out:
#        SizeRank  unemployment_rate  MORTGAGE30US     Avg Income
# 11852      8861               10.9          3.66   38614.649682
# 851        5296                7.1          4.45   75124.713772
# 24746       137                8.9          3.98   62408.122014
# 39790      2713                6.4          3.85   47099.074788
# 19215     10053                5.6          3.98   75125.628141
# 34081      1246                5.5          4.17   68319.057816
# 6715       1153               10.6          4.45   44651.378207
# 40785       347                5.4          3.85   47202.907712
# 45110       810                6.7          3.85   40420.506912
# 55283      9014                5.4          3.65   44588.926174
# 26694      6698                6.2          4.17   39556.135770
# 44745       175                6.8          3.85   36568.560735
# 8577       7937               13.1          3.66   60683.391003
# 53030      2408                2.9          3.65   67684.021544
# 20528      2701                6.1          3.98   46708.185053
# 20682       814                6.4          3.98   64832.427536
# 23677      7949                7.6          3.98   55730.337079
# 56407      8295                6.2          3.65   61172.279793
# 29614      1793                6.2          4.17   68814.683053
# 1264       8853                6.7          4.45   62116.306954
# 45591      1472                5.7          3.85  103769.841270
# 45940      2101                5.6          3.85   57875.079466
# 28077     10010                8.6          4.17   43712.574850
# 2400       8136                8.5          4.45   54440.380900
# 2000       1484                7.1          4.45   46077.288831
# 43628      3320                4.6          3.85   97165.532880
# 19317      7105                9.4          3.98   37569.316081
# 9687       4074                7.8          3.66   65257.064364
# 20107      4713                7.2          3.98   40625.000000
# 53187      5048                3.6          3.65   68276.173285
# ...         ...                ...           ...            ...
# 31959      9053                5.8          4.17   86310.975610
# 27204      3742                5.5          4.17   62247.474747
# 49714      2895                4.7          3.65   58325.812274
# 22926       947                5.1          3.98   67029.728344
# 57245      7097                7.6          3.65   98695.866142
# 37532     10432                4.1          3.85   56250.000000
# 19946      6137                6.7          3.98   58316.186557
# 8444       9828                8.7          3.66  102090.301003
# 51668       206                4.2          3.65   54585.129310
# 35730     10110                5.4          3.85   88055.555556
# 45413       636                5.0          3.85   75964.256866
# 21758      3870                4.6          3.98   80459.558824
# 54548      9368                5.1          3.65   57027.896996
# 32025      2037                7.0          4.17   41446.388682
# 36230      4704                4.5          3.85   55642.144638
# 31228      2668                5.2          4.17   50683.532370
# 43757      1114                5.0          3.85   55581.452404
# 7751       1075                9.0          4.45   60120.560091
# 49100      6372                4.3          3.65   63231.469441
# 20609      4172               10.1          3.98   40067.079463
# 32912      1713                5.8          4.17   56813.099042
# 21440      1298                4.4          3.98   63505.419281
# 52047      4776                6.8          3.65   39745.206862
# 7813       5320                9.7          4.45   44937.542012
# 43723      7981                4.8          3.85   53765.368852
# 50057      7147                7.2          3.65   38846.880907
# 32511       817                4.4          4.17   52398.989899
# 5192       5347                9.3          4.45   61994.376713
# 12172      5332                5.3          3.66   73296.545106
# 33003      2903                6.4          4.17   48011.617516
#
# [43486 rows x 4 columns]

# %%
# # first, create a normal neural network
# from keras.models import Sequential
# from keras.layers import Dense

# #optimize the shit out of it
# activation_types = ['relu', 'tanh', 'sigmoid']

# for i in range(30):
#     first_row = (i + 1) * 10
#     second_row = (i + 1) * 5
#     third_row = (i + 1) * 2
#     fourth_row = (i + 1)
#     for j in range(3):
#         model = Sequential()
#         model.add(Dense(units=first_row, activation='relu', input_dim=4))
#         model.add(Dense(units=second_row, activation=f'{activation_types[j]}'))
#         model.add(Dense(units=third_row, activation='relu'))
#         model.add(Dense(units=fourth_row, activation=f'{activation_types[j]}'))
#         model.add(Dense(units=1, activation='relu'))
#         # Compile the model
#         model.compile(optimizer='sgd',
#               loss='MSE',
#               metrics=['mae'])
#         # Fit the model to the training data
#         model.fit(
#             X_train,
#             y_train,
#             epochs=100,
#             shuffle=True,
#             verbose=0
#         )
#         model_loss, model_accuracy = model.evaluate(
#         X_train, y_train, verbose=0)
#         print('-----------------------------------------------------------------')
#         print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
#         print(f"This was iternation {i} sub level {j}")
#         print('-----------------------------------------------------------------')

# %%
# y_train

# %%
# from keras.models import Sequential
# from keras.layers import Dense


# model = Sequential()
# model.add(Dense(units=1000, activation='relu', input_dim=4))
# model.add(Dense(units=1, activation='relu'))
# # Compile the model
# model.compile(optimizer='adam',
#       loss='MSE',
#       metrics=['mae'])
# # Fit the model to the training data
# model.fit(
#     X_train,
#     y_train,
#     epochs=100,
#     shuffle=True,
#     verbose=1
# )
# model_loss, model_accuracy = model.evaluate(
# X_train, y_train, verbose=1)

# %%
# from sklearn.linear_model import Lasso, LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import auc
   
#Sets up the random forest regression model 
max_depth = 30
regr_multirf =RandomForestRegressor(n_estimators=500,
                                      max_depth=max_depth,
                                      verbose= 1,
                                      random_state=0)
#Fits to model
regr_multirf.fit(X_train, y_train)

# Predict on new data
y_multirf = regr_multirf.predict(X_test)

# How good are the features
print(regr_multirf.feature_importances_)
print(regr_multirf.score(X_test, y_test))
# print(sklearn.metrics.auc(X_train, y_train))
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
y = regr_multirf.predict(X_train)

# %%
X_train['Prediction'] = y
X_train['Actual'] = y_train
X_train.to_csv('Model_Output.csv')

# %%
regr_multirf.get_params
