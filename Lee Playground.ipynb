# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
from numpy.random import seed
seed(1)
import pandas as pd

# %%
#import the csv
df = pd.read_csv("complete_data_test1.csv")
# df1 = pd.read_excel('Zillow Data.xlsx')
# df = df.drop(columns=['Median Price', 'Date'])

# df['Sales'] = [float(x.replace(',', '')) for x in df['Sales']]
# df['Dollar Volume'] = [float(x.replace(',', '')) for x in df['Dollar Volume']]
# df['Average Price'] = [float(x.replace(',', '')) for x in df['Average Price']]
# df['Total Listings'] = [float(x.replace(',', '')) for x in df['Total Listings']]



# print(X.shape, y.shape)
df1 = df[['SizeRank', 'MedianValueSqft', 'MORTGAGE30US', 'unemployment_rate', 'Avg Income']]
df1

X = df1.drop("MedianValueSqft", axis=1)
y = df1["MedianValueSqft"]

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# X_train.shape
y_train.shape
# Out:
# (46693,)

# %%
# first, create a normal neural network
from keras.models import Sequential
from keras.layers import Dense

#optimize the shit out of it
activation_types = ['relu', 'tanh', 'sigmoid']

for i in range(30):
    first_row = (i + 1) * 10
    second_row = (i + 1) * 5
    third_row = (i + 1) * 2
    fourth_row = (i + 1)
    for j in range(3):
        model = Sequential()
        model.add(Dense(units=first_row, activation='relu', input_dim=4))
        model.add(Dense(units=second_row, activation=f'{activation_types[j]}'))
        model.add(Dense(units=third_row, activation='relu'))
        model.add(Dense(units=fourth_row, activation=f'{activation_types[j]}'))
        model.add(Dense(units=1, activation='relu'))
        # Compile the model
        model.compile(optimizer='sgd',
              loss='MSE',
              metrics=['mae'])
        # Fit the model to the training data
        model.fit(
            X_train,
            y_train,
            epochs=100,
            shuffle=True,
            verbose=0
        )
        model_loss, model_accuracy = model.evaluate(
        X_train, y_train, verbose=0)
        print('-----------------------------------------------------------------')
        print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
        print(f"This was iternation {i} sub level {j}")
        print('-----------------------------------------------------------------')

# %%
y_train
# Out:
# 10337     76.416667
# 14983     77.416667
# 47900    115.666667
# 33860    160.750000
# 30341     64.833333
# 45139     89.500000
# 47822     88.250000
# 31162     73.750000
# 10957     73.750000
# 18130    128.083333
# 49678    106.083333
# 19589    107.583333
# 27470     81.916667
# 37126     57.750000
# 31808     61.166667
# 26367     87.000000
# 5106      64.833333
# 32896     95.750000
# 46267    187.583333
# 40456    158.750000
# 13523    110.166667
# 10105     64.583333
# 9126      87.916667
# 62193    186.916667
# 43197    142.250000
# 48615     42.000000
# 44109     87.250000
# 7270      45.833333
# 25414    106.583333
# 50755     55.083333
#             ...
# 27204     71.166667
# 49714    132.333333
# 22926    101.583333
# 57245     53.333333
# 37532     82.250000
# 19946    167.166667
# 8444      60.916667
# 51668     76.666667
# 35730    111.750000
# 45413    111.000000
# 21758    247.833333
# 54548    156.916667
# 58546     49.000000
# 32025     52.333333
# 36230     38.500000
# 31228     89.083333
# 43757     72.583333
# 7751     126.000000
# 49100    676.333333
# 20609    136.750000
# 32912     54.000000
# 21440    139.166667
# 52047     55.333333
# 7813      84.416667
# 43723     80.333333
# 50057     63.250000
# 32511     43.166667
# 5192      37.166667
# 12172     86.916667
# 33003     79.083333
# Name: MedianValueSqft, Length: 46693, dtype: float64

# %%
from keras.models import Sequential
from keras.layers import Dense


model = Sequential()
model.add(Dense(units=1000, activation='relu', input_dim=4))
# Compile the model
model.compile(optimizer='sgd',
      loss='MSE',
      metrics=['mae'])
# Fit the model to the training data
model.fit(
    X_train,
    y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
model_loss, model_accuracy = model.evaluate(
X_train, y_train, verbose=0)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 5s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 2/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 3/100
#  - 2s - loss: 28247.3396 - mean_absolute_error: 125.3673
# Epoch 4/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 5/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 6/100
#  - 2s - loss: 28247.3396 - mean_absolute_error: 125.3673
# Epoch 7/100
#  - 2s - loss: 28247.3394 - mean_absolute_error: 125.3673
# Epoch 8/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 9/100
#  - 3s - loss: 28247.3394 - mean_absolute_error: 125.3673
# Epoch 10/100
#  - 3s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 11/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 12/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 13/100
#  - 2s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 14/100
#  - 3s - loss: 28247.3395 - mean_absolute_error: 125.3673
# Epoch 15/100

# %%
from sklearn.linear_model import Lasso, LinearRegression
model = Lasso(alpha=100)

# Fitting our model with all of our features in X
model.fit(X_train, y_train)

score = model.score(X_test, y_test)
print(f"R2 Score: {score}")

model.coef_
# Out:
# R2 Score: 0.29555552098977156
# array([-0.00449301, -0.        ,  0.        ,  0.00344964])

# %%
y = model.predict(X_train)

# %%
X_train['Prediction'] = y
X_train['Actual'] = y_train
X_train
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        SizeRank  MORTGAGE30US  unemployment_rate     Avg Income  Prediction  \
# 10337      5720          4.17                7.2   49581.984898  107.586348
# 14983     13111          4.17                4.1   54273.504274   90.562575
# 47900     10526          3.65                4.8   40760.869565   55.563335
# 33860      7465          3.85                3.3   84583.333333  220.487933
# 30341      8173          3.85                7.3   50122.549020   98.429754
# 45139     11740          3.65                6.3   66666.666667  139.474373
# 47822      5404          3.65                4.3   51865.256125  116.882590
# 31162      2309          3.85                4.9   46466.049383  112.163149
# 10957     11581          4.17                6.4   49684.343434   81.605943
# 18130       860          4.17                5.8   67029.755579  189.610796
# 49678     13460          3.65                5.2   56327.160494   96.078880
# 19589     10629          4.17                8.9   37706.611570   44.564480
# 27470      4610          3.85                4.9   41891.891892   86.045569
# 37126      6796          3.85                9.0   42005.300353   76.615077
# 31808     13714          3.85                4.0   55808.080808   93.147022
# 26367      9774          3.85                5.3   54087.452471  104.913923
# 5106      14640          4.17                6.4   42151.162791   41.875115
# 32896     12489          3.85                5.3   56106.870229   99.681668
# 46267      5759          3.65                4.7   88723.466981  242.434950
# 40456      3159          3.85                6.0   53173.154907  131.481161
# 13523     10587          4.17                6.4   53378.378378   98.815063
# 10105      4758          4.17                6.4   41190.944882   82.962593
# 9126       2651          4.17                7.6   52610.018727  131.820993
# 62193      8428          3.65                3.7   92771.084337  244.405922
# 43197      7387          3.65                4.3   60658.082976  138.305004
# 48615     13364          3.65                5.2   41208.791209   44.357352
# 44109     11121          3.65                4.6   55394.190871  103.369615
# 7270       2254          4.17                6.8   26984.597156   45.206363
# 25414      2232          3.85                4.1   49496.161228  122.961890
# 50755     14393          3.65                6.1   43509.615385   47.671053
# ...         ...           ...                ...            ...         ...
# 27204     13089          3.85                5.5   49541.284404   74.336989
# 49714       304          3.65                5.7   88935.643564  267.676226
# 22926     13238          3.85                4.7   55862.831858   95.474563
# 57245     11830          3.65                4.1   50652.985075   83.828645
# 37532     10322          3.85                4.2   55055.555556  105.791358
# 19946       803          4.17                5.6   64950.664951  182.694793
# 8444       5770          4.17                6.1   45869.974874   94.556618
# 51668      9296          3.65                4.7   51434.948980   97.911410
# 35730     11932          3.85                4.2   69028.662420  146.759739
# 45413      7962          3.65                4.1   66347.753744  155.348814
# 21758      7167          3.85                4.6  104630.214918  290.981274
# 54548      1335          3.65                3.6   79489.476041  230.458107
# 58546      9968          3.65                7.5   48732.718894   85.570403
# 32025     13499          3.85                4.1   47916.666667   66.890519
# 36230      2703          3.85                7.0   43774.206042  101.107027
# 31228     14017          3.85                5.9   53733.766234   84.630013
# 43757      9608          3.65                5.7   52043.726236   98.609652
# 7751       4791          4.17                5.9   42549.740484   87.501673
# 49100      6396          3.65                5.1  104971.910112  295.624105
# 20609      2811          4.17                5.8   88943.569554  256.439604
# 32912     12915          3.85                5.1   44396.551724   57.371322
# 21440     11644          3.85                3.1   66745.283019  140.176899
# 52047     11087          3.65                6.8   43937.500000   64.000975
# 7813       3002          4.17                5.8   56753.554502  144.537635
# 43723     13557          3.65                5.4   63988.095238  122.070488
# 50057     13048          3.65                6.8   46261.682243   63.207772
# 32511     11908          3.85                4.5   47733.918129   73.408474
# 5192      11594          4.17                6.9   41382.575758   52.909465
# 12172      6678          4.17                5.4   53852.739726  118.014594
# 33003      5298          3.85                5.8   54362.170088  125.972291
#
#            Actual
# 10337   76.416667
# 14983   77.416667
# 47900  115.666667
# 33860  160.750000
# 30341   64.833333
# 45139   89.500000
# 47822   88.250000
# 31162   73.750000
# 10957   73.750000
# 18130  128.083333
# 49678  106.083333
# 19589  107.583333
# 27470   81.916667
# 37126   57.750000
# 31808   61.166667
# 26367   87.000000
# 5106    64.833333
# 32896   95.750000
# 46267  187.583333
# 40456  158.750000
# 13523  110.166667
# 10105   64.583333
# 9126    87.916667
# 62193  186.916667
# 43197  142.250000
# 48615   42.000000
# 44109   87.250000
# 7270    45.833333
# 25414  106.583333
# 50755   55.083333
# ...           ...
# 27204   71.166667
# 49714  132.333333
# 22926  101.583333
# 57245   53.333333
# 37532   82.250000
# 19946  167.166667
# 8444    60.916667
# 51668   76.666667
# 35730  111.750000
# 45413  111.000000
# 21758  247.833333
# 54548  156.916667
# 58546   49.000000
# 32025   52.333333
# 36230   38.500000
# 31228   89.083333
# 43757   72.583333
# 7751   126.000000
# 49100  676.333333
# 20609  136.750000
# 32912   54.000000
# 21440  139.166667
# 52047   55.333333
# 7813    84.416667
# 43723   80.333333
# 50057   63.250000
# 32511   43.166667
# 5192    37.166667
# 12172   86.916667
# 33003   79.083333
#
# [46693 rows x 6 columns]
